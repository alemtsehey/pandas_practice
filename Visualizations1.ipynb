# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("icecreamratings.csv")

# %%
df = df.set_index("Date")

# %%
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot() #use SHIFT + TAB to see intellisense
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind = 'line', title = "Ice Cream Ratings")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %%
df.plot(kind = 'line', title = "Ice Cream Ratings", xlabel = "Daily ratings", ylabel = "Scores")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily ratings', ylabel='Scores'>

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df["Flavor Rating"].plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'barh', stacked = True)
# Out:
# <Axes: >

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter(x = "Texture Rating", y = "Overall Rating")
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = "Texture Rating", y = "Overall Rating", s = 100)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = "Texture Rating", y = "Overall Rating", s = 50, c = "yellow")
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
#histogram
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 100) #distribution
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y = "Flavor Rating")
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
df.plot.pie(y = "Flavor Rating", figsize = (10, 6))
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
#styling
df.plot(kind = 'line', title = "Ice Cream Ratings")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
df.plot(kind = 'line', title = "Ice Cream Ratings")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %%
plt.style.use('tableau-colorblind10')

# %%
df.plot(kind = 'line', title = "Ice Cream Ratings")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %%
plt.style.use('classic')

# %%
df.plot(kind = 'line', title = "Ice Cream Ratings")
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %% [markdown]
# **Exploratroy Data Analysis**

# %%
import seaborn as sns

# %%
df = pd.read_csv("world_population.csv")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           230.00           233.00           230.00
# mean  117.50      34632250.88      33600710.95      32066004.16
# std    67.69     137889172.44     135873196.61     131507146.34
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        406471.00        394295.00
# 50%   117.50       5762857.00       5456681.00       5244415.00
# 75%   175.75      22653719.00      21522626.00      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# min             596.00           651.00           700.00           733.00
# ...

# %%
df.isnull().sum() #missing datas
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by = "2022 Population").head()
# Out:
#      Rank CCA3           Country       Capital      Continent  \
# 226   234  VAT      Vatican City  Vatican City         Europe
# 209   233  TKL           Tokelau      Nukunonu        Oceania
# 150   232  NIU              Niue         Alofi        Oceania
# 64    231  FLK  Falkland Islands       Stanley  South America
# 137   230  MSR        Montserrat        Brades  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 226           510.00           520.00           564.00           596.00
# 209          1871.00          1827.00          1454.00          1367.00
# 150          1934.00          1942.00          1847.00          1812.00
# 64           3780.00          3747.00          3408.00          3187.00
# 137          4390.00          4500.00          5059.00          4938.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 226           651.00           700.00           733.00           752.00
# ...

# %%
df.sort_values(by = "2022 Population", ascending = False).head(15)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
# 102    11  JPN          Japan             Tokyo           Asia
# 63     12  ETH       Ethiopia       Addis Ababa         Africa
# 163    13  PHL    Philippines            Manila           Asia
# 57     14  EGY          Egypt             Cairo         Africa
# ...

# %%
#correlation
df.corr(numeric_only=True)
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.36            -0.36
# 2022 Population             -0.36             1.00             1.00
# 2020 Population             -0.36             1.00             1.00
# 2015 Population             -0.35             1.00             1.00
# 2010 Population             -0.35             1.00             1.00
# 2000 Population             -0.34             0.99             1.00
# 1990 Population             -0.33             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.34             0.97             0.98
# Area (km²)                  -0.38             0.45             0.45
# Density (per km²)            0.13            -0.03            -0.03
# Growth Rate                 -0.22            -0.02            -0.03
# World Population Percentage -0.36             1.00             1.00
#
# ...

# %%
#visualize it
sns.heatmap(df.corr(numeric_only=True), annot = True)
plt.rcParams['figure.figsize'] = (20, 7)
plt.show()

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
df.groupby('Continent').mean(numeric_only=True)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Asia           77.56      96327387.31      94955134.37      89165003.64
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
# South America  97.57      31201186.29      30823574.50      29509599.71
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa             18898197.31      14598365.95      11376964.52
# Asia               89087770.00      80580835.11      48639995.33
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
# ...

# %%
#what is in Oceania
df[df["Continent"].str.contains("Oceania")]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# ...

# %%
df.groupby('Continent').mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      96327387.31      94955134.37      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# ...

# %%
df1 = df.groupby('Continent').mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)

# %%
df1.plot()
# Out:
# <Axes: xlabel='Continent'>

# %%
df2 = df1.transpose()

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df1 = df.groupby('Continent').mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df1 = df.groupby('Continent')[['2022 Population',
       '2020 Population', '2015 Population', '2010 Population',
       '2000 Population', '1990 Population', '1980 Population',
       '1970 Population']].mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)

# %%
df1
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               96327387.31      94955134.37      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25455879.68      23871435.26      21419703.57
# Europe             15055371.82      14915843.92      15027454.12
# North America      15007403.40      14855914.82      14259596.25
# Oceania             2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
#
# ...

# %%
#or
df1 = df.groupby('Continent').mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)
cols = df.columns
df2 = df1[cols[5:13]]

# %%
df2
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               96327387.31      94955134.37      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25455879.68      23871435.26      21419703.57
# Europe             15055371.82      14915843.92      15027454.12
# North America      15007403.40      14855914.82      14259596.25
# Oceania             2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
#
# ...

# %%
#or
df1 = df.groupby('Continent')[df.columns[5:13]].mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)

# %%
df1
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia               96327387.31      94955134.37      89165003.64
# South America      31201186.29      30823574.50      29509599.71
# Africa             25455879.68      23871435.26      21419703.57
# Europe             15055371.82      14915843.92      15027454.12
# North America      15007403.40      14855914.82      14259596.25
# Oceania             2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# Oceania             1613163.65       1357512.09       1162774.87
#
# ...

# %%
df2 = df1.transpose()

# %%
df2
# Out:
# Continent              Asia  South America      Africa      Europe  \
# 2022 Population 96327387.31    31201186.29 25455879.68 15055371.82
# 2020 Population 94955134.37    30823574.50 23871435.26 14915843.92
# 2015 Population 89165003.64    29509599.71 21419703.57 15027454.12
# 2010 Population 89087770.00    26789395.54 18898197.31 14712278.68
# 2000 Population 80580835.11    25015888.69 14598365.95 14817685.71
# 1990 Population 48639995.33    21224743.93 11376964.52 14785203.94
# 1980 Population 40278333.33    17270643.29  8586031.98 14200004.52
# 1970 Population 43839877.83    13781939.71  6567175.27 13118479.82
#
# Continent        North America    Oceania
# 2022 Population    15007403.40 2046386.32
# 2020 Population    14855914.82 1910148.96
# 2015 Population    14259596.25 1756664.48
# 2010 Population    13568016.28 1613163.65
# 2000 Population    12151739.60 1357512.09
# 1990 Population    10531660.62 1162774.87
# 1980 Population     9207334.03  996532.17
# ...

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df1 = df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean(numeric_only=True).sort_values(by = "2022 Population", ascending = False)

# %%
df1
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               43839877.83      40278333.33      48639995.33
# South America      13781939.71      17270643.29      21224743.93
# Africa              6567175.27       8586031.98      11376964.52
# Europe             13118479.82      14200004.52      14785203.94
# North America       7885865.15       9207334.03      10531660.62
# Oceania              846968.26        996532.17       1162774.87
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               80580835.11      89087770.00      89165003.64
# South America      25015888.69      26789395.54      29509599.71
# Africa             14598365.95      18898197.31      21419703.57
# Europe             14817685.71      14712278.68      15027454.12
# North America      12151739.60      13568016.28      14259596.25
# Oceania             1357512.09       1613163.65       1756664.48
#
# ...

# %%
df2 = df1.transpose()

# %%
df2
# Out:
# Continent              Asia  South America      Africa      Europe  \
# 1970 Population 43839877.83    13781939.71  6567175.27 13118479.82
# 1980 Population 40278333.33    17270643.29  8586031.98 14200004.52
# 1990 Population 48639995.33    21224743.93 11376964.52 14785203.94
# 2000 Population 80580835.11    25015888.69 14598365.95 14817685.71
# 2010 Population 89087770.00    26789395.54 18898197.31 14712278.68
# 2015 Population 89165003.64    29509599.71 21419703.57 15027454.12
# 2020 Population 94955134.37    30823574.50 23871435.26 14915843.92
# 2022 Population 96327387.31    31201186.29 25455879.68 15055371.82
#
# Continent        North America    Oceania
# 1970 Population     7885865.15  846968.26
# 1980 Population     9207334.03  996532.17
# 1990 Population    10531660.62 1162774.87
# 2000 Population    12151739.60 1357512.09
# 2010 Population    13568016.28 1613163.65
# 2015 Population    14259596.25 1756664.48
# 2020 Population    14855914.82 1910148.96
# ...

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize = (20, 10))
# Out:
# <Axes: >

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df.select_dtypes(include = "number")
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36      41128771.00      38972230.00      33753499.00      28189672.00
# 1     138       2842321.00       2866849.00       2882481.00       2913399.00
# 2      34      44903225.00      43451666.00      39543154.00      35856344.00
# 3     213         44273.00         46189.00         51368.00         54849.00
# 4     203         79824.00         77700.00         71746.00         71519.00
# ..    ...              ...              ...              ...              ...
# 229   226         11572.00         11655.00         12182.00         13142.00
# 230   172        575986.00        556048.00        491824.00        413296.00
# 231    46      33696614.00      32284046.00      28516545.00      24743946.00
# 232    63      20017675.00      18927715.00              NaN      13792086.00
# 233    74      16320537.00      15669666.00      14154937.00      12839771.00
#
# ...

# %%
df.select_dtypes(include = "object")
# Out:
#     CCA3            Country           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara          El Aaiún    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %%
df.select_dtypes(include = "float")
# Out:
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# 2        44903225.00      43451666.00      39543154.00      35856344.00
# 3           44273.00         46189.00         51368.00         54849.00
# 4           79824.00         77700.00         71746.00         71519.00
# ..               ...              ...              ...              ...
# 229         11572.00         11655.00         12182.00         13142.00
# 230        575986.00        556048.00        491824.00        413296.00
# 231      33696614.00      32284046.00      28516545.00      24743946.00
# 232      20017675.00      18927715.00              NaN      13792086.00
# 233      16320537.00      15669666.00      14154937.00      12839771.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#    total_bill   tip     sex smoker  day       time  size
# 0       16.99  1.01  Female     No  Sun      Lunch     2
# 1       10.34  1.66    Male     No  Sat     Dinner     3
# 2       21.01  3.50    Male     No  Sun  Breakfast     3
# 3       23.68  3.31    Male     No  Sun     Dinner     2
# 4       24.59  3.61  Female     No  Mon      Snack     4
# 5       25.29  4.71    Male     No  Sun     Dinner     4
# 6        8.77  2.00    Male     No  Wed     Dinner     2
# 7       26.88  3.12    Male     No  Sun      Lunch     4
# 8       15.04  1.96    Male     No  Fri     Dinner     2
# 9       14.78  3.23    Male     No  Sun  Breakfast     2

# %%
#Scatter
df.plot.scatter(x = 'day', y = 'tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
df.plot.scatter(x='total_bill', y='tip', title='Total Bill vs Tip')
# Out:
# <Axes: title={'center': 'Total Bill vs Tip'}, xlabel='total_bill', ylabel='tip'>

# %%
avg_tip_by_day = df.groupby('day')['tip'].mean()
avg_tip_by_day.plot(kind='bar', title='Average Tip by Day')
# Out:
# <Axes: title={'center': 'Average Tip by Day'}, xlabel='day'>

# %%
df['total_bill'].plot.hist(bins=5, title='Distribution of Total Bill')
# Out:
# <Axes: title={'center': 'Distribution of Total Bill'}, ylabel='Frequency'>

# %%
df.boxplot(column='total_bill', by='size')
# Out:
# <Axes: title={'center': 'total_bill'}, xlabel='size'>

# %%
df.plot.line(x='total_bill', y='tip', title='Total Bill vs Tip (Line Plot)')
# Out:
# <Axes: title={'center': 'Total Bill vs Tip (Line Plot)'}, xlabel='total_bill'>

# %%
#customizing plots
df.plot.scatter(x='total_bill', y='tip', color='blue', alpha=0.5, title='Total Bill vs Tip')
# Out:
# <Axes: title={'center': 'Total Bill vs Tip'}, xlabel='total_bill', ylabel='tip'>

# %%
df['total_bill'].plot.hist(bins=5, color='purple', title='Distribution of Total Bill')
# Out:
# <Axes: title={'center': 'Distribution of Total Bill'}, ylabel='Frequency'>

# %%
# Area plot of total bill over time (assuming time is sequential)
df.plot.area(x='time', y='total_bill', title='Total Bill Over Time')
# Out:
# <Axes: title={'center': 'Total Bill Over Time'}, xlabel='time'>

# %%
df
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sat  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Mon  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Wed  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Fri  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#      Make Colour  Odometer  Doors        Price
# 0  Toyota  White    150043      4   $4,000.00
# 1   Honda    Red     87899      4   $5,000.00
# 2  Toyota   Blue     32549      3   $7,000.00
# 3     BMW  Black     11179      5  $22,000.00
# 4  Nissan  White    213095      4   $3,500.00
# 5  Toyota  Green     99213      4   $4,500.00
# 6   Honda   Blue     45698      4   $7,500.00
# 7   Honda   Blue     54738      4   $7,000.00
# 8  Toyota  White     60000      4   $6,250.00
# 9  Nissan  White     31600      4   $9,700.00

# %%
#You can visualize a column by calling .plot() on it.
df["Odometer"].plot()
# Out:
# <Axes: >

# %%
#Or compare two columns by passing them as x and y to plot().
df.plot(x = "Make", y = "Odometer")
# Out:
# <Axes: xlabel='Make'>

# %% [raw]
# You can see the distribution of a column by calling .hist() on you.
#
# The distribution of something is a way of describing the spread of different values.

# %%
df["Odometer"].hist() #default 10 bins : int or sequence, default 10 Number of histogram bins to be used.
# Out:
# <Axes: >

# %% [raw]
# In this case, the majority of the distribution (spread) of the "Odometer (KM)" column is more towards the left of the graph. And there are two values which are more to the right. These two values to the right could be considered outliers (not part of the majority).
#
# Now what if we wanted to plot our "Price" column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      10 non-null     object
#  1   Colour    10 non-null     object
#  2   Odometer  10 non-null     int64
#  3   Doors     10 non-null     int64
#  4   Price     10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df
# Out:
#      Make Colour  Odometer  Doors        Price
# 0  Toyota  White    150043      4   $4,000.00
# 1   Honda    Red     87899      4   $5,000.00
# 2  Toyota   Blue     32549      3   $7,000.00
# 3     BMW  Black     11179      5  $22,000.00
# 4  Nissan  White    213095      4   $3,500.00
# 5  Toyota  Green     99213      4   $4,500.00
# 6   Honda   Blue     45698      4   $7,500.00
# 7   Honda   Blue     54738      4   $7,000.00
# 8  Toyota  White     60000      4   $6,250.00
# 9  Nissan  White     31600      4   $9,700.00

# %%
# Change Price column to integers
df["Price"] = df["Price"].str.replace('[\$\,\.]', '', regex=True)
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\byene\AppData\Local\Temp\ipykernel_9832\3549899996.py:2: SyntaxWarning: invalid escape sequence '\$'
#   df["Price"] = df["Price"].str.replace('[\$\,\.]', '', regex=True)
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White    150043      4   400000
# 1   Honda    Red     87899      4   500000
# 2  Toyota   Blue     32549      3   700000
# 3     BMW  Black     11179      5  2200000
# 4  Nissan  White    213095      4   350000
# 5  Toyota  Green     99213      4   450000
# 6   Honda   Blue     45698      4   750000
# 7   Honda   Blue     54738      4   700000
# 8  Toyota  White     60000      4   625000
# 9  Nissan  White     31600      4   970000

# %%
# Remove 2 extra zeros from the price column (2200000 -> 22000) by indexing all but the last two digits
df["Price"] = df["Price"].str[:-2].astype(int)
df
# Out:
#      Make Colour  Odometer  Doors   Price
# 0  Toyota  White    150043      4   40000
# 1   Honda    Red     87899      4   50000
# 2  Toyota   Blue     32549      3   70000
# 3     BMW  Black     11179      5  220000
# 4  Nissan  White    213095      4   35000
# 5  Toyota  Green     99213      4   45000
# 6   Honda   Blue     45698      4   75000
# 7   Honda   Blue     54738      4   70000
# 8  Toyota  White     60000      4   62500
# 9  Nissan  White     31600      4   97000

# %%
df.dtypes
# Out:
# Make        object
# Colour      object
# Odometer     int64
# Doors        int64
# Price        int32
# dtype: object

# %%
df["Price"].plot()
# Out:
# <Axes: >

# %%
#World Happiness Report Dataset
df = pd.read_csv('whr.csv')

# %%
df
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 148                    Rwanda             151            3.471  0.368746
# 149                     Syria             152            3.462  0.777153
# 150                  Tanzania             153            3.349  0.511136
# 151                   Burundi             154            2.905  0.091623
# 152  Central African Republic             155            2.693  0.000000
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# ...

# %%
# 1. Bar Chart: Average Happiness Score by Region
avg = df.groupby('Region')["Happiness Score"].mean()
avg.plot()
# Out:
# <Axes: xlabel='Region'>

# %%
avg.plot(title = "Average Happiness Score", xlabel = "Region", ylabel = "Average Happiness Score")
# Out:
# <Axes: title={'center': 'Average Happiness Score'}, xlabel='Region', ylabel='Average Happiness Score'>

# %%
avg.plot(title = "Average Happiness Score", xlabel = "Region", ylabel = "Average Happiness Score", rot = 45)
# Out:
# <Axes: title={'center': 'Average Happiness Score'}, xlabel='Region', ylabel='Average Happiness Score'>

# %%
#2. Scatter Plot: Relationship between Economy and Happiness Score
df.plot(x = 'Economy', y = 'Happiness Score', kind = 'scatter')
# Out:
# <Axes: xlabel='Economy', ylabel='Happiness Score'>

# %%
import pandas as pd

# Example data
data = pd.Series([1, 3, 5, 7, 9])
data
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv('student.csv')
df
# Out:
#    StudentID      Name  Age Gender  Math  Science  English  History  Geography
# 0          1     Alice   15      F    85       92       88       74         81
# 1          2       Bob   14      M    79       78       85       69         74
# 2          3   Charlie   16      M    95       89       91       82         87
# 3          4     David   15      M    67       76       72       70         65
# 4          5       Eve   14      F    74       81       79       85         77
# 5          6     Frank   16      M    88       90       84       88         89
# 6          7     Grace   15      F    92       85       94       80         88
# 7          8    Hannah   14      F    81       84       87       76         79
# 8          9       Ian   16      M    90       86       89       75         83
# 9         10  Jennifer   15      F    86       87       82       81         86

# %%
# Line plot using Pandas
df.plot()
# Out:
# <Axes: >

# %%
df.plot(x = 'Name' , y = ['Math', 'English', 'Science'], figsize = (15, 3))
# Out:
# <Axes: xlabel='Name'>

# %%
df['Math'].plot(kind = 'hist', bins =10, color = 'lightgreen')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x = 'Name', y = 'Math')
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot(x = 'Name', y = ['Math', 'English'])
# Out:
# <Axes: xlabel='Name'>

# %%
df['avg'] = df[['Math', 'Science', 'English', 'History', 'Geography']].mean(axis = 1)
df.plot(kind = 'bar', x = 'Name', y = 'avg')
# Out:
# <Axes: xlabel='Name'>

# %%
df['Math'].plot(kind = 'hist', color = 'green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['Math', 'English']].plot(kind = 'hist', bins = 25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#df.plot(kind = 'bar')
df.plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.plot(kind = 'box', vert = False, figsize = (9, 6))
# Out:
# <Axes: >

# %%
# Box plot of scores in all subjects
df[['Math', 'Science', 'English', 'History', 'Geography']].plot(kind='box', title='Box Plot of Scores')
# Out:
# <Axes: title={'center': 'Box Plot of Scores'}>

# %%
# Scatter plot between Math and Science scores
df.plot(kind='scatter', x='Math', y='Science', title='Scatter Plot of Math vs Science Scores', color='orange')
# Out:
# <Axes: title={'center': 'Scatter Plot of Math vs Science Scores'}, xlabel='Math', ylabel='Science'>

# %% [raw]
# Area Plot
# An area plot is an extension of a line chart that fills the region between the line chart and the x-axis with a color. If more than one area chart displays in the same plot, different colors distinguish different area charts. Let's try it out:

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'area', figsize = (9, 6))
# Out:
# <Axes: >
