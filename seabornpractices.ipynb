# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Built in datasets in Seaborn**

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
# Load an example dataset
tips = sns.load_dataset("tips")

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Load an example dataset
exercise = sns.load_dataset("exercise")

exercise.sample(10)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 66          66  23  low fat     98   1 min  running
# 73          73  25  low fat    110  15 min  running
# 72          72  25  low fat     94   1 min  running
# 20          20   7   no fat     90  30 min     rest
# 80          80  27   no fat    140  30 min  running
# 3            3   2  low fat     90   1 min     rest
# 55          55  19   no fat     98  15 min  walking
# 51          51  18   no fat     92   1 min  walking
# 41          41  14  low fat    100  30 min  walking
# 8            8   3  low fat     94  30 min     rest

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 36        16.31  2.00    Male     No   Sat  Dinner     3
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 70        12.02  1.97    Male     No   Sat  Dinner     2
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2

# %%
sns.lineplot(x = "day", y = "tip", data = tips)
plt.show()

# %%
sns.lineplot(x = "day", y = "tip", data = tips, errorbar = None)
plt.show()

# %% [markdown]
# **The colored area in the sns.lineplot() is a confidence interval.**
# Seaborn, by default, calculates and displays a confidence interval around the line plot. This interval represents the uncertainty in the estimated relationship between the x and y variables.
#
# **Here's how it works:**
#
# * Data points: The line plot is based on the average 'tip' value for each 'day'.
# * Confidence interval: Seaborn calculates a confidence interval for each point on the line. This interval represents a range within which the true average 'tip' value for that 'day' is likely to fall.
# * Shaded area: The shaded area represents the confidence interval. It's usually shaded with a lighter color than the line itself.

# %% [markdown]
# **To control the confidence interval:**
#
# * Disable it: You can disable the confidence interval by setting ci=None in the sns.lineplot() function:

# %%
sns.lineplot(x = 'day', y = 'tip', data = tips, errorbar = None) #ci is deprecated
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.lineplot(x = 'day', y = 'tip', data = tips, errorbar = ('ci', 95)) #ci is 95%
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.histplot(x = "total_bill", data = tips)
plt.show()

# %%
sns.kdeplot(x = "total_bill", data = tips, fill = True)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x = 'day', y = 'total_bill',data = tips)
plt.show()

# %%
sns.lineplot(x = 'size', y = 'total_bill', data = tips)
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.violinplot(y="day", x="total_bill", data=tips)
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue = "day")
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", size="size", sizes=(50, 200), data=tips)
plt.show()

# %% [markdown]
# **hue="sex":** This parameter tells Seaborn to color-code the points based on the values in the "sex" column. This means you'll have different colored points for male and female customers.

# %% [markdown]
# **size="size":** This parameter tells Seaborn to adjust the size of the points based on the values in the "size" column. The larger the value in the "size" column, the larger the point will be on the plot.

# %% [markdown]
# **sizes=(50, 200):** This parameter defines the range of sizes for the points. The smallest point will have a size of 50, and the largest point will have a size of 200.

# %%
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(data=tips, hue="sex")
plt.show()

# %%
# Load an csv dataset
df = pd.read_csv("student.csv")

df
# Out:
#    StudentID      Name  Age Gender  Math  Science  English  History  Geography
# 0          1     Alice   15      F    85       92       88       74         81
# 1          2       Bob   14      M    79       78       85       69         74
# 2          3   Charlie   16      M    95       89       91       82         87
# 3          4     David   15      M    67       76       72       70         65
# 4          5       Eve   14      F    74       81       79       85         77
# 5          6     Frank   16      M    88       90       84       88         89
# 6          7     Grace   15      F    92       85       94       80         88
# 7          8    Hannah   14      F    81       84       87       76         79
# 8          9       Ian   16      M    90       86       89       75         83
# 9         10  Jennifer   15      F    86       87       82       81         86

# %% [markdown]
# ## Distribution Plots (KDE and Histogram)
# You can visualize the distribution of students' scores in each subject using KDE plots or histograms.
#
# KDE Plot for Math Scores

# %%
sns.kdeplot(x = 'Math', data = df)
# Out:
# <Axes: xlabel='Math', ylabel='Density'>

# %%
sns.kdeplot(x = 'Math', data = df, fill = True)
plt.title("Distribution of Math Scores")
plt.show()

# %% [markdown]
# ## Hist for Science scores ##

# %%
sns.histplot(x = "Science", data = df)
# Out:
# <Axes: xlabel='Science', ylabel='Count'>

# %%
sns.histplot(x = "Science", data = df, kde = True)
# Out:
# <Axes: xlabel='Science', ylabel='Count'>

# %% [markdown]
# ## Box plot
# Box plots are great for visualizing the distribution of scores and identifying outliers.

# %%
sns.boxplot(x = "Math", y = "Gender", hue = "Age", data = df)
# Out:
# <Axes: xlabel='Math', ylabel='Gender'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Let me briefly explain the above plot.**
#
# * The bottom black horizontal line of the box plot is the minimum value
# * The first black horizontal line of the rectangle shape of the box plot is the first quartile or 25%
# * The second black horizontal line of the rectangle shape of the box plot is Second quartile or 50% or median.
# * The third black horizontal line of rectangle shape of the same box plot is third quartile or 75%
# * The top black horizontal line of the rectangle shape of the box plot is the maximum value.
# * The small diamond shape of the box plot is outlier data.

# %% [markdown]
# ##  Pair Plot
# Pair plots are useful for exploring the relationships between multiple numerical variables.

# %%
sns.pairplot(df, hue = "Gender")
plt.show()

# %% [markdown]
# ## Explanation of sns.pairplot(df, hue="Gender")
# The **sns.pairplot()** function in Seaborn creates a grid of scatter plots for each pair of numerical variables in your dataset.
#
# Here's a breakdown of what happens when you run *sns.pairplot(students, hue="Gender")*:
#
# **Pairwise Scatter Plots:**
#
# For each pair of numerical variables (like Math vs. Science, Science vs. English, etc.), Seaborn creates a scatter plot.
# The x-axis of each scatter plot represents one variable, while the y-axis represents another variable.
#
# **Diagonal Plots:**
#
# The diagonal of the grid typically shows the distribution of each individual variable. By default, Seaborn uses histograms, but if KDE is enabled, it would show density plots.
# For example, the diagonal might show the distribution of Math scores or Science scores across all students.
#
# **Coloring by Gender (hue="Gender"):**
#
# The **hue parameter** is used to color-code the scatter plots based on a categorical variable—in this case, Gender.
# Male and female students will be represented by different colors (e.g., blue for males and orange for females).
# This allows you to visually assess whether there are any noticeable differences in the relationships between variables based on gender.
#
# **Interpreting the Pair Plot:**
#
# **Scatter Plots:** Each scatter plot allows you to explore the relationship between two variables. For example, you might see whether higher Math scores tend to correspond with higher Science scores and whether this trend differs between genders.
#
# **Histograms/Distributions:** The diagonal plots let you see the distribution of scores within each subject. You can quickly assess whether the distribution of scores is similar between genders or if one gender tends to have higher or lower scores.
#
# **Trend Analysis:** By examining the scatter plots, you can identify trends or correlations between subjects, as well as any potential outliers. For example, if the Math and Science scatter plot shows a clear upward trend for both genders, it suggests a positive correlation between these two subjects.

# %% [markdown]
# **Visual Insights:**
#
# **Correlation:** You can observe if certain subjects are strongly correlated. For instance, if students who score high in Math also tend to score high in Science, this will be visible in the scatter plot for Math vs. Science.
#
# **Gender Differences:** By using the hue parameter, you can easily compare how male and female students perform across different subjects. If one gender consistently outperforms the other in certain subjects, this may be apparent in the scatter plots.
#
# **Outliers:** Any outliers—students whose scores are significantly different from others—can be identified in the scatter plots. For example, a student with very high Math scores but low scores in other subjects might stand out.

# %% [markdown]
# **Understanding the KDE on the Diagonal**
# **Single Variable Distribution:** On the diagonal of the pairplot, each plot corresponds to the distribution of a single numerical variable (e.g., Math, Science, English, etc.) within the dataset.
#
# **What is Being Plotted:** For instance, if the diagonal plot shows a KDE for Math, it represents the distribution of Math scores across all students. Similarly, there will be separate KDEs for Science, English, History, and Geography.
#
# **Purpose:** The purpose of the KDE on the diagonal is to provide a visual understanding of how each variable (e.g., Math scores) is distributed across the dataset.
# It helps you see things like:
#
# The central tendency (where most scores lie).
#
# The spread (how wide or narrow the distribution is).
#
# The presence of multiple peaks (indicating clusters or subgroups within the data).
#
# Any skewness or outliers.

# %% [markdown]
# **Swarm Plot**
#
# Swarm plots are useful for showing the distribution of data points and their spread.

# %%
sns.swarmplot(data=df, x="Gender", y="Math")
plt.title('Swarm Plot of Math Scores by Gender')
plt.show()

# %%
sns.histplot(x='Math', data=df)
plt.show()

# %%
sns.scatterplot(x='Math', y='English', data=df)
plt.show()

# %%
sns.kdeplot(x='Math',data=df)
plt.show()

# %%
sns.kdeplot(x='English', data=df)
plt.show()

# %%
res = sns.kdeplot(x='Math', y='English', data=df, color='blue', fill=True)
plt.title('KDE Plot: Math vs. English Scores')
plt.xlabel('Math Score')
plt.ylabel('English Score')
plt.show()

# %% [raw]
# This code will generate a KDE plot that shows the joint distribution of Math and English scores for all students in your dataset. The plot will have a shaded area representing the estimated probability density, highlighting areas where the data is more concentrated.

# %% [markdown]
# **Using color palettes within a Seaborn Kdeplot**

# %%
sns.kdeplot(x='Math', y='English', data=df, hue='Gender', palette='viridis')
plt.show()

# %% [raw]
# 'viridis' is a sequential color palette that ranges from green to yellow, providing a visually appealing and informative color scheme.

# %% [markdown]
# **Other Color Palettes:**
#
# Seaborn offers a wide variety of color palettes to choose from. Here are some popular options:
#
# **Sequential:** These palettes have a gradual change in color intensity. Examples: 'viridis', 'magma', 'plasma', 'inferno', 'cividis'
#
# **Diverging:** These palettes have two distinct colors at the extremes and a neutral color in the middle. Examples: 'coolwarm', 'bwr', 'RdBu', 'RdGy', 'BrBG'
#
# **Qualitative:** These palettes have distinct colors for each category. Examples: 'Set1', 'Set2', 'Set3', 'pastel1', 'pastel2', 'bright'

# %%
sns.kdeplot(x='Math', y='English', data=df, hue='Gender', palette='coolwarm')
plt.savefig('cover.png')

# %%
df = sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
## Themes in matplotlib and seaborn
#plt.scatter(df.speeding,df.alcohol)
#plt.show()
sns.scatterplot(x = 'speeding', y = 'alcohol', data = df)
plt.show()

# %%
#plt.scatter(df['speeding'],df['alcohol'])
#sns.set_style("whitegrid")
#plt.show()
sns.scatterplot(x = 'speeding', y = 'alcohol', data = df)
sns.set_style("whitegrid")
plt.show()

# %% [markdown]
# **Here are a few of the popular themes:**
#
# Darkgrid
#
# Whitegrid
#
# Dark
#
# White
#
# Ticks

# %%
sns.scatterplot(x = 'speeding', y = 'alcohol', data = df)
sns.set_style("ticks")
plt.show()

# %% [markdown]
# **axis spines**

# %% [raw]
# But we usually don’t make our plots as the above one as we do not include the top and right axis spines. We can remove the top and right axis spines using the despine() function.

# %%
sns.scatterplot(x = 'speeding', y = 'alcohol',data = df)
sns.set_style("ticks")
sns.despine() #sns.despine() removes unnecessary spines from the plot.
plt.show()

# %% [markdown]
# **Seaborn Color Palette**

# %% [markdown]
# Seaborn has a reputation for making plots and graphs more attractive using attractive colors and color combinations. In data visualization, color is necessarily involved, and colors have an influence on their observer.Color plays an important role than any other aspect in the visualizations. When used effectively, color adds more value to the plot.
#
# **A palette means** a flat surface on which a painter arranges and mixes paints.

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='size', palette='viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='day', palette='coolwarm')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='day', y='tip', data=tips, hue='sex', palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
# Getting all available color palette names (only built-ins), others are part of matplotlib
all_palettes = sns.palettes.SEABORN_PALETTES.keys()
print(list(all_palettes))
# Out:
# ['deep', 'deep6', 'muted', 'muted6', 'pastel', 'pastel6', 'bright', 'bright6', 'dark', 'dark6', 'colorblind', 'colorblind6']

# %% [markdown]
# **Hue parameter**

# %%
# Sample data
data = {
    'Age': [15, 16, 15, 16, 15, 16, 15, 16, 15, 16, 15, 16],
    'Score': [85, 78, 92, 88, 90, 75, 80, 85, 82, 77, 89, 91],
    'Gender': ['Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Age  Score  Gender
# 0    15     85  Female
# 1    16     78    Male
# 2    15     92    Male
# 3    16     88  Female
# 4    15     90  Female
# 5    16     75    Male
# 6    15     80  Female
# 7    16     85    Male
# 8    15     82  Female
# 9    16     77    Male
# 10   15     89  Female
# 11   16     91    Male

# %%
# Scatter plot without hue
sns.scatterplot(data=df, x='Age', y='Score')
plt.title('Scatter plot of Age vs Score')
plt.show()

# %%
# Scatter plot with hue
sns.scatterplot(data=df, x='Age', y='Score', hue='Gender')
plt.title('Scatter plot of Age vs Score with Gender')
plt.show()

# %% [raw]
# In the second plot, the data points are colored differently based on the Gender category, making it easier to see if there are any differences in scores between males and females.

# %%
# Bar plot without hue
sns.barplot(data=df, x='Age', y='Score')
plt.title('Bar plot of Age vs Score')
plt.show()

# %%
# Bar plot with hue
sns.barplot(data=df, x='Age', y='Score', hue='Gender')
plt.title('Bar plot of Age vs Score with Gender')
plt.show()

# %% [raw]
# In the second plot, the bars are split by Gender, allowing you to compare the average scores of males and females at different ages.

# %%
# Box plot without hue
sns.boxplot(data=df, x='Age', y='Score')
plt.title('Box plot of Age vs Score')
plt.show()

# %%
# Box plot with hue
sns.boxplot(data=df, x='Age', y='Score', hue='Gender')
plt.title('Box plot of Age vs Score with Gender')
plt.show()

# %% [raw]
# In the second plot, the box plots are split by Gender, allowing you to see the distribution of scores for males and females at different ages.

# %% [markdown]
# **Histograms are useful for visualizing the distribution of a single variable.**

# %%
sns.histplot(df['Score'], kde=True)
plt.title('Histogram of Scores')
plt.show()

# %% [raw]
# In a histogram, the x-axis represents the range of values (bins) that the data falls into, and the y-axis represents the frequency or count of data points within each bin. Let's break down how these values are computed
#
# Explanation
# X-Axis (Score): The x-axis represents the range of scores. The bins are automatically determined by Seaborn based on the range of the data.
#
# Y-Axis (Frequency): The y-axis represents the count of scores within each bin. For example, if there are multiple scores in the range of 80-90, the corresponding bar will be taller.
#
# KDE Line: The KDE line shows the estimated probability density of the scores. It provides a smooth curve that represents the distribution of the data.

# %%
df
# Out:
#     Age  Score  Gender
# 0    15     85  Female
# 1    16     78    Male
# 2    15     92    Male
# 3    16     88  Female
# 4    15     90  Female
# 5    16     75    Male
# 6    15     80  Female
# 7    16     85    Male
# 8    15     82  Female
# 9    16     77    Male
# 10   15     89  Female
# 11   16     91    Male

# %% [markdown]
# <h1>Excel File</h1>

# %%
import seaborn as sns
#load the tips built-in dataset
tips = sns.load_dataset('tips')

# %%
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2

# %%
#save the dataset to an excel file
tips.to_excel('tips.xlsx', index = False)

# %% [markdown]
# <h2>Loading the Excel file back into pandas </h2>

# %%
import pandas as pd

# Load the Excel file into a DataFrame
tips_from_excel = pd.read_excel('tips.xlsx')

# Display the first few rows of the dataset
tips_from_excel.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <h2>Using the DataFrame with Seaborn</h2>

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of total bill vs tip, colored by time of day
sns.scatterplot(data=tips_from_excel, x='total_bill', y='tip', hue='time')
plt.title('Scatter plot of Total Bill vs Tip')
plt.show()

# %%
# Create a box plot of total bill by day of the week
sns.boxplot(data=tips_from_excel, x='day', y='total_bill', hue='sex')
plt.title('Box plot of Total Bill by Day of the Week')
plt.show()

# %%
# Create a histogram of total bill with KDE
sns.histplot(tips_from_excel['total_bill'], kde=True)
plt.title('Histogram of Total Bill')
plt.show()

# %% [markdown]
# <h2>Saving the tips Dataset to a CSV File</h2>

# %%
import seaborn as sns

# Load the tips dataset
tips = sns.load_dataset('tips')

# Save the dataset to a CSV file
tips.to_csv('tips.csv', index=False)

# %%
import pandas as pd

# Load the CSV file into a DataFrame
tips_from_csv = pd.read_csv('tips.csv')

# Display the first few rows of the dataset
print(tips_from_csv.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <h2>Saving the tips Dataset to a Text File</h2>

# %%
import seaborn as sns

# Load the tips dataset
tips = sns.load_dataset('tips')

# Save the dataset to a text file
tips.to_csv('tips.txt', index=False, sep='\t')  # Using tab as the separator for better readability

# %% [markdown]
# <h2>Loading the Text File Back into Pandas</h2>

# %%
import pandas as pd

# Load the text file into a DataFrame
tips_from_txt = pd.read_csv('tips.txt', sep='\t')

# Display the first few rows of the dataset
print(tips_from_txt.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <h2> From Database (mysql) </h2>
# <h5>Install pymsql first</h5>

# %%
#conn = 'mysql+pymysql://your_username:your_password@localhost/your_database'
#Establish a connection to your SQL database using the mysql+pymysql connector. 
conn = 'mysql+pymysql://root:root@localhost/bookregister' #conda install pymysql

# Read data from SQL table into a Pandas DataFrame
df = pd.read_sql_query('SELECT * FROM books', conn)

# Explore the data using Pandas
df.head()
# Out:
#    id          bookname bookedition  bookprice
# 0   3         Dertogada           7      300.0
# 1   5  Enterprise Java            1      345.0
# 2   6  Enterprise Java            1      345.0
# 3   7            Python           2       23.0
# 4   8              Java           4      234.0

# %%
#conn = 'mysql+pymysql://your_username:your_password@localhost/your_database'
#Establish a connection to your SQL database using the mysql+pymysql connector. 
conn = 'mysql+pymysql://root:root@localhost/craftstudentsdb' #conda install pymysql

# Read data from SQL table into a Pandas DataFrame
df = pd.read_sql_query('SELECT * FROM users', conn)

# Explore the data using Pandas
df.head()
# Out:
#    user_id username   password
# 0      111    Abebe   abebe123
# 1      222   Kebede  Kebede123
# 2      222     King      kingo

# %%
print(df.describe())  # Get descriptive statistics
# Out:
#               id   bookprice
# count  18.000000   18.000000
# mean   12.444444  197.388889
# std     5.436502   99.356245
# min     3.000000   23.000000
# 25%     8.250000  123.000000
# 50%    12.500000  234.000000
# 75%    16.750000  234.000000
# max    21.000000  345.000000

# %%
print(df.info())  # Get information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           18 non-null     int64
#  1   bookname     18 non-null     object
#  2   bookedition  18 non-null     object
#  3   bookprice    18 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes
# None
